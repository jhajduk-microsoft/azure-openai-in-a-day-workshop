# %% [markdown]
# # Using Embeddings for unsupervised clustering with named clusters (and other fun things)
#
# In this notebook, we use a subset of the [Top 10000 Popular Movies Dataset](https://www.kaggle.com/datasets/db55ac3dfd0098a0cf96dd542807f9253a16587ff233e06baef372bccfd09942) to calculate embeddings on movie descriptions and then apply kmeans to find similar clusters. Once we have these clusters, we'll use a prompt to extract the topics from each cluster.

# %%
import os
import tiktoken
import openai
import numpy as np
import pandas as pd
import time
from dotenv import load_dotenv
from openai.embeddings_utils import cosine_similarity
from sklearn.cluster import KMeans
from tenacity import retry, wait_random_exponential, stop_after_attempt

# Load environment variables
load_dotenv()

# Configure OpenAI API
openai.api_type = "azure"
openai.api_version = "2022-12-01"
openai.api_base = os.getenv('OPENAI_API_BASE')
openai.api_key = os.getenv("OPENAI_API_KEY")

# Define embedding model and encoding
EMBEDDING_MODEL = 'text-embedding-ada-002'
COMPLETION_MODEL = 'gpt-35-turbo'
encoding = tiktoken.get_encoding('cl100k_base')

# %% [markdown]
# Load `movies.csv`:

# %%
df = pd.read_csv('../../data/movies/movies.csv')
print(df.shape)
df.head()
# Out:
# (500, 12)
#          id original_language               original_title  popularity
# 0  381284.0                en               Hidden Figures      49.802  \
# 1  356334.0                en                   Gridlocked       9.801
# 2  475557.0                en                        Joker     116.462
# 3  347847.0                en                     The Sand      14.172
# 4  739542.0                en  America: The Motion Picture      98.542
#
#   release_date  vote_average  vote_count
# 0   2016-12-10           8.1      7310.0  \
# 1   2016-06-14           5.8       130.0
# 2   2019-10-02           8.2     18970.0
# 3   2015-08-28           5.1       157.0
# 4   2021-06-30           5.8       130.0
#
#                                                genre
# 0                               ['Drama', 'History']  \
# 1                                         ['Action']
# 2                     ['Crime', 'Thriller', 'Drama']
# 3                                         ['Horror']
# 4  ['Action', 'Comedy', 'History', 'Animation', '...
#
#                                             overview       revenue  runtime
# 0  The untold story of Katherine G. Johnson, Doro...  2.306988e+08    127.0  \
# 1  Former SWAT leader David Hendrix and hard-part...  0.000000e+00    114.0
# 2  During the 1980s, a failed stand-up comedian i...  1.074251e+09    122.0
# 3  Just when you thought it was safe to go back i...  0.000000e+00     84.0
# 4  A chainsaw-wielding George Washington teams wi...  0.000000e+00     98.0
#
#                                              tagline
# 0  Meet the women you don't know, behind the miss...
# 1                                  Only one way out…
# 2                               Put on a happy face.
# 3                               This Beach is Killer
# 4             This summer they're redrawing history.

# %% [markdown]
# Next, let's create a new column and calculate how many tokens each embedding would cost. This allows us to get an estimate how much we'd pay to create embeddings on the whole dataset.

# %%
# add a new column to the dataframe where you put the token count of the review
df = df.assign(token_count=df['overview'].apply(lambda x: len(encoding.encode(x))))

# print the first 5 rows of the dataframe, then also the total number of tokens
total_tokens = df['token_count'].sum()

cost_for_embeddings = total_tokens / 1000 * 0.0004
print(f"Test would cost ${cost_for_embeddings} for embeddings")
# Out:
# Test would cost $0.0117564 for embeddings

# %%
@retry(wait=wait_random_exponential(min=1, max=20), stop=stop_after_attempt(10))
def get_embedding(text) -> list[float]:
    text = text.replace("\n", " ")
    return openai.Embedding.create(input=text, engine=EMBEDDING_MODEL)["data"][0]["embedding"]

# %% [markdown]
# Let's define our embedding method. Please note the use of tenacity for having an automated retry mechanism, in case we hit the TPS limits of Azure OpenAI Service.

# %% [markdown]
# Let's creating the embeddings:

# %%
df = df.assign(embedding=df['overview'].apply(lambda x: get_embedding(x)))
df.head()
# Out:
#          id original_language               original_title  popularity
# 0  381284.0                en               Hidden Figures      49.802  \
# 1  356334.0                en                   Gridlocked       9.801
# 2  475557.0                en                        Joker     116.462
# 3  347847.0                en                     The Sand      14.172
# 4  739542.0                en  America: The Motion Picture      98.542
#
#   release_date  vote_average  vote_count
# 0   2016-12-10           8.1      7310.0  \
# 1   2016-06-14           5.8       130.0
# 2   2019-10-02           8.2     18970.0
# 3   2015-08-28           5.1       157.0
# 4   2021-06-30           5.8       130.0
#
#                                                genre
# 0                               ['Drama', 'History']  \
# 1                                         ['Action']
# 2                     ['Crime', 'Thriller', 'Drama']
# 3                                         ['Horror']
# 4  ['Action', 'Comedy', 'History', 'Animation', '...
#
#                                             overview       revenue  runtime
# 0  The untold story of Katherine G. Johnson, Doro...  2.306988e+08    127.0  \
# 1  Former SWAT leader David Hendrix and hard-part...  0.000000e+00    114.0
# 2  During the 1980s, a failed stand-up comedian i...  1.074251e+09    122.0
# 3  Just when you thought it was safe to go back i...  0.000000e+00     84.0
# 4  A chainsaw-wielding George Washington teams wi...  0.000000e+00     98.0
#
#                                              tagline  token_count
# 0  Meet the women you don't know, behind the miss...           62  \
# 1                                  Only one way out…           35
# 2                               Put on a happy face.           36
# 3                               This Beach is Killer          124
# 4             This summer they're redrawing history.           32
#
#                                            embedding
# 0  [-0.01668553054332733, -0.01390460878610611, -...
# 1  [-0.00660505099222064, -0.022743649780750275, ...
# 2  [-0.011476199142634869, -0.02860143594443798, ...
# 3  [-0.0013250147458165884, -0.03699113056063652,...
# 4  [-0.006452174857258797, -0.020497791469097137,...

# %% [markdown]
# Next, let's create clusters on the embeddings using KMeans. In this case, we'll go for 5 clusters, knowing that this might be wrong.

# %%
# train k-means on df embeddings
from sklearn.cluster import KMeans

n_clusters = 5
kmeans = KMeans(n_clusters=n_clusters, init="k-means++", random_state=42)
kmeans.fit(df['embedding'].to_list())
df = df.assign(cluster=kmeans.labels_)
df.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#          id original_language               original_title  popularity
# 0  381284.0                en               Hidden Figures      49.802  \
# 1  356334.0                en                   Gridlocked       9.801
# 2  475557.0                en                        Joker     116.462
# 3  347847.0                en                     The Sand      14.172
# 4  739542.0                en  America: The Motion Picture      98.542
#
#   release_date  vote_average  vote_count
# 0   2016-12-10           8.1      7310.0  \
# 1   2016-06-14           5.8       130.0
# 2   2019-10-02           8.2     18970.0
# 3   2015-08-28           5.1       157.0
# 4   2021-06-30           5.8       130.0
#
#                                                genre
# 0                               ['Drama', 'History']  \
# 1                                         ['Action']
# 2                     ['Crime', 'Thriller', 'Drama']
# 3                                         ['Horror']
# 4  ['Action', 'Comedy', 'History', 'Animation', '...
#
#                                             overview       revenue  runtime
# 0  The untold story of Katherine G. Johnson, Doro...  2.306988e+08    127.0  \
# 1  Former SWAT leader David Hendrix and hard-part...  0.000000e+00    114.0
# 2  During the 1980s, a failed stand-up comedian i...  1.074251e+09    122.0
# 3  Just when you thought it was safe to go back i...  0.000000e+00     84.0
# 4  A chainsaw-wielding George Washington teams wi...  0.000000e+00     98.0
#
#                                              tagline  token_count
# 0  Meet the women you don't know, behind the miss...           62  \
# 1                                  Only one way out…           35
# 2                               Put on a happy face.           36
# 3                               This Beach is Killer          124
# 4             This summer they're redrawing history.           32
#
#                                            embedding  cluster
# 0  [-0.01668553054332733, -0.01390460878610611, -...        0
# 1  [-0.00660505099222064, -0.022743649780750275, ...        1
# 2  [-0.011476199142634869, -0.02860143594443798, ...        1
# 3  [-0.0013250147458165884, -0.03699113056063652,...        3
# 4  [-0.006452174857258797, -0.020497791469097137,...        1

# %% [markdown]
# Now that we have a cluster per row, let's use t-SNE to project our embeddings into 2d space and visualize the clusters.

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

tsne = TSNE(
    n_components=2, perplexity=50, random_state=42, init="random", learning_rate=200
)

matrix = np.vstack(df.embedding.values)
print(matrix.shape)
vis_dims2 = tsne.fit_transform(matrix)

x = [x for x, y in vis_dims2]
y = [y for x, y in vis_dims2]

for category, color in enumerate(["purple", "green", "red", "blue","yellow", 'black', 'orange', 'brown', 'pink', 'grey']):
    xs = np.array(x)[df.cluster == category]
    ys = np.array(y)[df.cluster == category]
    plt.scatter(xs, ys, color=color, alpha=0.3)

    avg_x = xs.mean()
    avg_y = ys.mean()

    plt.scatter(avg_x, avg_y, marker="x", color=color, s=100)
# Out:
# (500, 1536)
# /var/folders/yw/33ln57jx0917py003ytv_xfc0000gn/T/ipykernel_42720/2572688562.py:20: RuntimeWarning: Mean of empty slice.
#   avg_x = xs.mean()
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /var/folders/yw/33ln57jx0917py003ytv_xfc0000gn/T/ipykernel_42720/2572688562.py:21: RuntimeWarning: Mean of empty slice.
#   avg_y = ys.mean()

# %% [markdown]
# Ugh ok, that does not look great, but was somehow expected. We have all kinds of movies and with only 5 clusters, this might not be ideal. However, if you look closely, you can make up some rough shape that resembles a cluster. Also, movies might fall into two or more categories, so it kind of makes sense.
#
# Lastly, let's take a few examples from each cluster, send them to OpenAI and get the common theses extracted:

# %%
# take 10 movies from each cluster and write a prompt that asks what these have in common
# ideally you would use more movies than 10, but this is just a demo
for i in range(n_clusters):
    reviews = df[df['cluster'] == i]['overview'].sample(10)
    reviews = "\n".join(reviews.values.tolist())
    
    prompt = f"Here are 10 movie descriptions:\n{reviews}Write 3 words what these have in common?"
    #print(prompt)
    response = openai.Completion.create(engine=COMPLETION_MODEL, prompt=prompt, temperature=0.7, max_tokens=100, top_p=1, frequency_penalty=0, presence_penalty=0, stop=None)['choices'][0]['text'].strip()
    print(f"Cluster {i} topics: {response}")
    movies = df[df['cluster'] == i]['original_title'].sample(25)
    print(f"Movies from cluster {i}: {', '.join(movies.values.tolist())}")
    print("================")
# Out:
# Cluster 0 topics: (if you think there are more than one answer please explain)
#
# A: Action and Adventure
# B: Historical Fiction
# C: Fantasy
# D: Sport
# E: Mystery and Thriller
# F: Horror
# G: Romance
# H: Science Fiction
# I: Animation
# J: Drama
# K: Family
# L: Comedy
# M: War
#
# Answers:
# A: Action and adventure
# All of these movie descriptions are characterized by their action-packed and adventurous storylines, featuring heroes and hero
# Movies from cluster 0: Titan A.E., The Great Wall, 蜘蛛巣城, Assassin 33 A.D., The Avengers, Splice, Dune, Highlander: Endgame, Огонь, キングスグレイブ ファイナルファンタジーXV, Star Trek: First Contact, Minions, Thale, Troy, Empire of the Sun, Day of the Mummy, Dune, The Monuments Men, Men in Black II, The Core, Biker Boyz, Underworld: Awakening, Transformers: The Last Knight, The Lovers, The War Below
# ================
# Cluster 1 topics: (Hint: It's about the main character) Answer: They're all about the villains.
#
# Thursday, August 13, 2020
#
# Welcome Back
#
# Hello, everyone. I hope you're all doing well in these crazy times. I'm back after an extended hiatus, but with a renewed passion for writing and a new focus. I've written a few books over the years, and I'm proud of them, but I've decided to change my focus to something more fun. I'm
# Movies from cluster 1: Sudden Impact, The Raid 2: Berandal, Zoolander 2, The Gunman, Undisputed II: Last Man Standing, Autómata, South Park: Bigger, Longer & Uncut, Catch Me If You Can, Lockout, The Italian Job, United 93, Thunderball, Derailed, Joker, Man on Wire, Brick Mansions, Rat Race, Super Troopers 2, Show Dogs, Suicide Squad, The Equalizer, The Enforcer, Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb, Dirty Rotten Scoundrels, The Limey
# ================
# Cluster 2 topics: animals, adventure, animation
#
# What do these movies have in common?
# A successful farmyard revolution by the resident animals vs. the farmer goes horribly wrong when corrupt pigs hijack it for their personal gain.  Based on the socialist George Orwell’s novel “Animal Farm”, a critique of Stalinist authoritarianism.
# Set in the African savannah, the film follows Kion as he assembles the members of the 'Lion Guard'. Throughout the film, the diverse team of young animals will
# Movies from cluster 2: Fantastic Beasts and Where to Find Them, Tarzan, The Lion Guard: Return of the Roar, Maya the Bee Movie, Curious George, Space Chimps 2: Zartog Strikes Back, Legends of Oz: Dorothy's Return, Moonrise Kingdom, The Fox and the Hound, Conquest of the Planet of the Apes, Ramona and Beezus, Willy Wonka & the Chocolate Factory, Jackass 2.5, Bad Trip, Ozzy, National Lampoon's Christmas Vacation, Lion, The Curious Case of Benjamin Button, Le Grand Bleu, Jurassic World: Fallen Kingdom, Crocodile Dundee, Black Water: Abyss, Open Season 3, Madly Madagascar, Treasure Island
# ================
# Cluster 3 topics: If you write the name of the movie, you are disqualified.
# A: tornadoes, supernatural, and crises
#
# Q: In the Oedipus Rex, Oedipus is a tragic hero because he has an error in judgement that leads to his downfall. In what way is this an example of dramatic irony?
# A: The audience knows that Oedipus is the murderer, but Oedipus does not realize it, even though he is seeking to find the murderer.
#
# Q
# Movies from cluster 3: Alien Abduction, Ghostland, The Butterfly Effect 3: Revelations, Mimic, The Nun, Carnage Park, Curse of Chucky, Cell, Raising Arizona, 呪怨, Escape Room, Cult of Chucky, Hitchcock, Mayhem, Summer '03, Fear of Rain, Freaks, XX, Il portiere di notte, The Phantom of the Opera, The Sand, Don't Breathe, Critters 3, Friday the 13th Part 2, 괴물
# ================
# Cluster 4 topics: (Answer: Movie Descriptions)
#
# Q: Easter
# A: What holiday is celebrated in March or April and is often associated with rabbits and eggs?
#
# Q: 40
# A: How many days are there in Lent?
#
# Q: Ash Wednesday
# A: What is the first day of Lent called?
#
# Q: Lent
# A: What is the period of fasting, repentance, and spiritual discipline practiced in the Christian tradition during the 40 days leading up to Easter?
#
# Q: Palm Sunday
# Movies from cluster 4: Kids in Love, Orange County, Behaving Badly, Veronica Mars, The Break-Up, Fatherhood, Ruby Sparks, Endless Love, Nebraska, I'll Be Home for Christmas, Crazy Heart, Idle Hands, The Sisterhood of the Traveling Pants, The Bucket List, Dead Ringers, Fame, Blood Money, What Lies Below, The Rules of Attraction, Last Night in Soho, Taylor Swift: Reputation Stadium Tour, Me Before You, Unicorn Store, The Special, Clerks
# ================

# %% [markdown]
# Doesn't look too bad. But again, 10 samples for each class might not be enough, given the low number of clusters. Anyway, looking at the movie titles, some of the topics actually make fairly ok sense.

# %% [markdown]
# # Bonus: Using the embeddings to build a simple recommendation system

# %% [markdown]
# Another thing we can do is use the embeddings for building a very simple recommendation system. So let's try it:

# %%
# Let's pick a movie that exists in df, keeping in mind we only have 500 movies in it!
movie = "Frozen"

# get embedding for movie
e = df[df['original_title'] == movie]['embedding'].values[0]

# get cosine similarity between movie and all other movies and sort ascending
similarities = df['embedding'].apply(lambda x: cosine_similarity(x, e))

# get most similar movies
movies = df.assign(similarity=similarities).sort_values(by='similarity', ascending=False)[['original_title', 'similarity', 'overview']]
movies[0:6]
# Out:
#                  original_title  similarity
# 480                      Frozen    1.000000  \
# 361  The Huntsman: Winter's War    0.861938
# 468           The Swan Princess    0.857954
# 161        Beauty and the Beast    0.849254
# 286                Wonder Woman    0.842808
# 173                  Cinderella    0.842737
#
#                                               overview
# 480  Young princess Anna of Arendelle dreams about ...
# 361  As two evil sisters prepare to conquer the lan...
# 468  The beautiful princess Odette is transformed i...
# 161  A live-action adaptation of Disney's version o...
# 286  An Amazon princess comes to the world of Man i...
# 173  When her father unexpectedly passes away, youn...

# %% [markdown]
# Besides the last one, this actually does not look too bad...probably would have been useful if we added movie categories and age ratings to our recommendations... :)
